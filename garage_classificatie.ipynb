# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Garage Classificatie - Decision Tree

# %%
# Stap 2: Data inlezen
df = pd.read_excel('AmesHousing.xlsx', sheet_name='AmesHousing')
print(f"Dataset shape: {df.shape}")
print(f"Kolommen: {df.columns.tolist()}")
# Out:
# Dataset shape: (1460, 12)
# Kolommen: ['Garage Type', 'Neighborhood', 'House Style', 'Gr Liv Area', 'Year Built', 'Lot Area', 'Full Bath', 'Overall Qual', 'Total Bsmt SF', 'Bedroom AbvGr', 'Garage Cars', 'SalePrice']

# %%
df['Garage_Target'] = df['Garage Type'].apply(lambda x: 'yes' if pd.notna(x) else 'no')

exp1_features = ['Gr Liv Area', 'Lot Area', 'Neighborhood']
exp1_target = 'Garage_Target'
print(f"Experiment 1 - Features: {exp1_features}")
print(f"Experiment 1 - Target: {exp1_target}")
# Out:
# Experiment 1 - Features: ['Gr Liv Area', 'Lot Area', 'Neighborhood']
# Experiment 1 - Target: Garage_Target

# %%
df_exp1 = df[exp1_features + [exp1_target]].copy()
df_exp1 = pd.get_dummies(df_exp1, columns=['Neighborhood'], drop_first=False)

feature_cols_exp1 = [col for col in df_exp1.columns if col != exp1_target]
X1 = df_exp1[feature_cols_exp1]
y1 = df_exp1[exp1_target]
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.15, random_state=42)

# Stap 5: Initialize en train decision tree
dt1 = DecisionTreeClassifier(max_depth=4, min_samples_split=20, random_state=42)
dt1.fit(X1_train, y1_train)

y1_pred = dt1.predict(X1_test)
acc1 = accuracy_score(y1_test, y1_pred)
prec1 = precision_score(y1_test, y1_pred, pos_label='yes', zero_division=0)
rec1 = recall_score(y1_test, y1_pred, pos_label='yes', zero_division=0)
f1_1 = f1_score(y1_test, y1_pred, pos_label='yes', zero_division=0)

print(f"\nExperiment 1 Results:")
print(f"Accuracy: {acc1:.4f}")
print(f"Precision: {prec1:.4f}")
print(f"Recall: {rec1:.4f}")

# Decision tree
tree_text1 = export_text(dt1, feature_names=feature_cols_exp1)
print(f"\nTree:")
print(tree_text1)
# Out:
# Experiment 1 Results:
# Accuracy: 0.8356
# Precision: 0.8387
# Recall: 0.9945
#
# Tree:
# |--- Gr Liv Area <= 784.00
# |   |--- Lot Area <= 55348.00
# |   |   |--- class: yes
# |   |--- Lot Area >  55348.00
# |   |   |--- class: no
# |--- Gr Liv Area >  784.00
# |   |--- Lot Area <= 7184.00
# |   |   |--- class: yes
# |   |--- Lot Area >  7184.00
# |   |   |--- Lot Area <= 7317.00
# |   |   |   |--- class: no
# |   |   |--- Lot Area >  7317.00
# |   |   |   |--- Gr Liv Area <= 3682.00
# |   |   |   |   |--- class: yes
# |   |   |   |--- Gr Liv Area >  3682.00
# |   |   |   |   |--- class: yes

# %%
# EXPERIMENT 2: Meer features
exp2_features = ['Gr Liv Area', 'Lot Area', 'Neighborhood', 'House Style', 'Year Built']

df_exp2 = df[exp2_features + [exp1_target]].copy()
df_exp2 = pd.get_dummies(df_exp2, columns=['Neighborhood', 'House Style'], drop_first=False)

feature_cols_exp2 = [col for col in df_exp2.columns if col != exp1_target]
X2 = df_exp2[feature_cols_exp2]
y2 = df_exp2[exp1_target]
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.15, random_state=42)

dt2 = DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, random_state=42)
dt2.fit(X2_train, y2_train)

y2_pred = dt2.predict(X2_test)
acc2 = accuracy_score(y2_test, y2_pred)
prec2 = precision_score(y2_test, y2_pred, pos_label='yes', zero_division=0)
rec2 = recall_score(y2_test, y2_pred, pos_label='yes', zero_division=0)
f1_2 = f1_score(y2_test, y2_pred, pos_label='yes', zero_division=0)

print(f"\nExperiment 2 Results:")
print(f"Accuracy: {acc2:.4f}")
print(f"Precision: {prec2:.4f}")
print(f"Recall: {rec2:.4f}")

tree_text2 = export_text(dt2, feature_names=feature_cols_exp2)
print(f"\nTree:")
print(tree_text2)
# Out:
# Experiment 2 Results:
# Accuracy: 0.8356
# Precision: 0.8451
# Recall: 0.9836
#
# Tree:
# |--- Gr Liv Area <= 784.00
# |   |--- Year Built <= 1957.50
# |   |   |--- class: no
# |   |--- Year Built >  1957.50
# |   |   |--- class: yes
# |--- Gr Liv Area >  784.00
# |   |--- Lot Area <= 7184.00
# |   |   |--- class: yes
# |   |--- Lot Area >  7184.00
# |   |   |--- Gr Liv Area <= 3682.00
# |   |   |   |--- Year Built <= 1882.50
# |   |   |   |   |--- Lot Area <= 149737.50
# |   |   |   |   |   |--- class: yes
# |   |   |   |   |--- Lot Area >  149737.50
# |   |   |   |   |   |--- Year Built <= 1877.50
# |   |   |   |   |   |   |--- class: yes
# |   |   |   |   |   |--- Year Built >  1877.50
# |   |   |   |   |   |   |--- class: yes
# |   |   |   |--- Year Built >  1882.50
# |   |   |   |   |--- Year Built <= 1893.50
# |   |   |   |   |   |--- Gr Liv Area <= 3308.00
# |   |   |   |   |   |   |--- class: yes
# |   |   |   |   |   |--- Gr Liv Area >  3308.00
# ...

# %%
# EXPERIMENT 3: Meer features, diepere boom
exp3_features = ['Gr Liv Area', 'Lot Area', 'Neighborhood', 'House Style', 'Year Built', 'Full Bath', 'Overall Qual']

df_exp3 = df[exp3_features + [exp1_target]].copy()
df_exp3 = pd.get_dummies(df_exp3, columns=['Neighborhood', 'House Style'], drop_first=False)

feature_cols_exp3 = [col for col in df_exp3.columns if col != exp1_target]
X3 = df_exp3[feature_cols_exp3]
y3 = df_exp3[exp1_target]
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size=0.15, random_state=42)

dt3 = DecisionTreeClassifier(max_depth=8, min_samples_split=10, random_state=42)
dt3.fit(X3_train, y3_train)

y3_pred = dt3.predict(X3_test)
acc3 = accuracy_score(y3_test, y3_pred)
prec3 = precision_score(y3_test, y3_pred, pos_label='yes', zero_division=0)
rec3 = recall_score(y3_test, y3_pred, pos_label='yes', zero_division=0)
f1_3 = f1_score(y3_test, y3_pred, pos_label='yes', zero_division=0)

print(f"\nExperiment 3 Results:")
print(f"Accuracy: {acc3:.4f}")
print(f"Precision: {prec3:.4f}")
print(f"Recall: {rec3:.4f}")

tree_text3 = export_text(dt3, feature_names=feature_cols_exp3)
print(f"\nTree:")
print(tree_text3)
# Out:
# Experiment 3 Results:
# Accuracy: 0.8311
# Precision: 0.8380
# Recall: 0.9891
#
# Tree:
# |--- Gr Liv Area <= 784.00
# |   |--- House Style_SLvl <= 0.50
# |   |   |--- Lot Area <= 49943.00
# |   |   |   |--- class: yes
# |   |   |--- Lot Area >  49943.00
# |   |   |   |--- Lot Area <= 141885.50
# |   |   |   |   |--- class: no
# |   |   |   |--- Lot Area >  141885.50
# |   |   |   |   |--- class: yes
# |   |--- House Style_SLvl >  0.50
# |   |   |--- class: yes
# |--- Gr Liv Area >  784.00
# |   |--- Lot Area <= 7184.00
# |   |   |--- class: yes
# |   |--- Lot Area >  7184.00
# |   |   |--- Lot Area <= 7317.00
# |   |   |   |--- class: no
# |   |   |--- Lot Area >  7317.00
# |   |   |   |--- Gr Liv Area <= 3682.00
# |   |   |   |   |--- Year Built <= 2009.50
# |   |   |   |   |   |--- Overall Qual <= 2.50
# |   |   |   |   |   |   |--- Year Built <= 1975.50
# |   |   |   |   |   |   |   |--- Lot Area <= 62092.00
# |   |   |   |   |   |   |   |   |--- class: yes
# ...

# %%
# EXPERIMENT 4 veel features maar ondiepe boom
exp4_features = ['Gr Liv Area', 'Lot Area', 'Neighborhood', 'House Style', 'Year Built', 'Full Bath', 'Overall Qual', 'Total Bsmt SF', 'Bedroom AbvGr']

df_exp4 = df[exp4_features + [exp1_target]].copy()
df_exp4 = pd.get_dummies(df_exp4, columns=['Neighborhood', 'House Style'], drop_first=False)

feature_cols_exp4 = [col for col in df_exp4.columns if col != exp1_target]
X4 = df_exp4[feature_cols_exp4]
y4 = df_exp4[exp1_target]
X4_train, X4_test, y4_train, y4_test = train_test_split(X4, y4, test_size=0.15, random_state=42)

dt4 = DecisionTreeClassifier(max_depth=5, min_samples_split=15, random_state=42)
dt4.fit(X4_train, y4_train)

y4_pred = dt4.predict(X4_test)
acc4 = accuracy_score(y4_test, y4_pred)
prec4 = precision_score(y4_test, y4_pred, pos_label='yes', zero_division=0)
rec4 = recall_score(y4_test, y4_pred, pos_label='yes', zero_division=0)
f1_4 = f1_score(y4_test, y4_pred, pos_label='yes', zero_division=0)

print(f"\nExperiment 4 Results:")
print(f"Accuracy: {acc4:.4f}")
print(f"Precision: {prec4:.4f}")
print(f"Recall: {rec4:.4f}")

tree_text4 = export_text(dt4, feature_names=feature_cols_exp4)
print(f"\nTree:")
print(tree_text4)
# Out:
# Experiment 4 Results:
# Accuracy: 0.8356
# Precision: 0.8387
# Recall: 0.9945
#
# Tree:
# |--- Gr Liv Area <= 784.00
# |   |--- House Style_SLvl <= 0.50
# |   |   |--- Lot Area <= 49943.00
# |   |   |   |--- class: yes
# |   |   |--- Lot Area >  49943.00
# |   |   |   |--- class: no
# |   |--- House Style_SLvl >  0.50
# |   |   |--- class: yes
# |--- Gr Liv Area >  784.00
# |   |--- Lot Area <= 7184.00
# |   |   |--- class: yes
# |   |--- Lot Area >  7184.00
# |   |   |--- Lot Area <= 7317.00
# |   |   |   |--- class: no
# |   |   |--- Lot Area >  7317.00
# |   |   |   |--- Total Bsmt SF <= 4691.50
# |   |   |   |   |--- Neighborhood_Suburbs <= 0.50
# |   |   |   |   |   |--- class: yes
# |   |   |   |   |--- Neighborhood_Suburbs >  0.50
# |   |   |   |   |   |--- class: yes
# |   |   |   |--- Total Bsmt SF >  4691.50
# |   |   |   |   |--- Total Bsmt SF <= 4995.50
# |   |   |   |   |   |--- class: yes
# |   |   |   |   |--- Total Bsmt SF >  4995.50
# ...
